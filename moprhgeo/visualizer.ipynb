# %%
import folium
import ast
from IPython.display import display
import mercantile
from shapely import geometry

import sparql_virtualizer
import rdflib

g = rdflib.Graph()


query = """
PREFIX ogc: <http://www.ogc.org/>
PREFIX ine: <https://lod.ine.es/voc/cubes/vocabulary#>
PREFIX sdmx-measure: <http://purl.org/linked-data/sdmx/2009/measure#>
PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX geof: <http://www.opengis.net/def/function/geosparql/>
PREFIX ex: <http://example.org/function/>
PREFIX qb: <http://purl.org/linked-data/cube#>
PREFIX dbo: <http://dbpedia.org/ontology/>

SELECT ?x ?geom WHERE {
    # ?x a dbo:RailwayStation ;
        geo:hasGeometry ?geom .
FILTER ( 
geof:sfContains(
    "POLYGON((-9.085693 42.592935, -7.668457 42.592935, -7.668457 43.244952, -9.085693 43.244952, -9.085693 42.592935))"^^geo:wktLiteral, 
    # ?geom)
)
}
"""

qres = g.query(query)

# 1. Configuración base
# Usamos un mapa base oscuro para que los bordes de colores resalten más
m = folium.Map(location=[40.41, -3.70], zoom_start=6, tiles='CartoDB positron')
puntos_para_encuadre = []

# Paleta de colores más brillantes para que destaquen sobre fondo oscuro y con bordes
colores_paleta = ['#3498db', '#e74c3c', '#2ecc71', '#f1c40f', '#9b59b6', '#e67e22']

for row in qres:
    # Iteramos sobre la fila de 2 en 2
    for i in range(0, len(row), 2):
        try:
            uri = str(row[i])
            raw_geom = str(row[i+1])
            
            if not raw_geom.startswith("{"):
                continue

            geom_dict = ast.literal_eval(raw_geom)
            
            # Selección de color
            color_index = (i // 2) % len(colores_paleta)
            color_actual = colores_paleta[color_index]
            
            # CONFIGURACIÓN DE ESTILO PARA EVITAR OPACIDAD
            # Usamos una opacidad de relleno MUY baja (0.1 o 0.2)
            # Pero una opacidad de borde ALTA (1.0) y un peso de línea mayor
            def style_function(feature, color=color_actual):
                return {
                    'fillColor': color,   # Color de relleno
                    'fillOpacity': 0.01,   # MUY TRANSPARENTE por dentro (15%)
                    'color': color,       # Color del borde
                    'opacity': 1.0,        # BORDE TOTALMENTE OPACO
                    'weight': 3,          # BORDE GRUESO para que se vea bien el contorno
                }
            
            # Añadir al mapa con el estilo modificado
            folium.GeoJson(
                geom_dict,
                tooltip=f"<b>Variable {i//2 + 1}:</b> {uri}",
                style_function=style_function
            ).add_to(m)
            
            # Recolectar coordenadas para auto-zoom
            if 'coordinates' in geom_dict:
                coords = geom_dict['coordinates']
                if geom_dict['type'] == 'Polygon':
                    # Manejo de Polígonos y MultiPolígonos si fuera necesario
                    p = coords[0][0] # Primer punto del primer anillo
                    puntos_para_encuadre.append([p[1], p[0]])
                elif geom_dict['type'] == 'Point':
                    puntos_para_encuadre.append([coords[1], coords[0]])
                    
        except Exception:
            # Capturar errores de parsing de geometría o valores nulos
            continue

# 2. Ajuste de vista
if puntos_para_encuadre:
    m.fit_bounds(puntos_para_encuadre)

display(m)
# Out:
# https://api-features.idee.es//collections/railwaystationnode/items?f=json&limit=10000&bbox=-9.085693%2C42.592935%2C-7.668457%2C43.244952
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbd2e71568ec25faa6add74e7c661f9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbd2e71568ec25faa6add74e7c661f9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbd2e71568ec25faa6add74e7c661f9b = L.map(
#                 &quot;map_bbd2e71568ec25faa6add74e7c661f9b&quot;,
#                 {
#                     center: [40.41, -3.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50fdd57b0bae039d48a9e373bfcf72eb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50fdd57b0bae039d48a9e373bfcf72eb.addTo(map_bbd2e71568ec25faa6add74e7c661f9b);
#
#
#         function geo_json_f8f40e594da57c960e5e94b151ea230a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#3498db&quot;, &quot;fillColor&quot;: &quot;#3498db&quot;, &quot;fillOpacity&quot;: 0.01, &quot;opacity&quot;: 1.0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_f8f40e594da57c960e5e94b151ea230a_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_f8f40e594da57c960e5e94b151ea230a = L.geoJson(null, {
#                 onEachFeature: geo_json_f8f40e594da57c960e5e94b151ea230a_onEachFeature,
#
#                 style: geo_json_f8f40e594da57c960e5e94b151ea230a_styler,
#             ...{
# }
#         });
#
#         function geo_json_f8f40e594da57c960e5e94b151ea230a_add (data) {
#             geo_json_f8f40e594da57c960e5e94b151ea230a
#                 .addData(data);
#         }
#             geo_json_f8f40e594da57c960e5e94b151ea230a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-8.41856539561964, 43.16770119510385, 400.5200000000041], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_f8f40e594da57c960e5e94b151ea230a.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Variable 1:&lt;/b&gt; https://api-features.idee.es//collections/railwaystationnode/items/FCEST_N150240000134
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             geo_json_f8f40e594da57c960e5e94b151ea230a.addTo(map_bbd2e71568ec25faa6add74e7c661f9b);
#
#
#         function geo_json_1a6108940dbc6741999a1de2d359f0dd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#3498db&quot;, &quot;fillColor&quot;: &quot;#3498db&quot;, &quot;fillOpacity&quot;: 0.01, &quot;opacity&quot;: 1.0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_1a6108940dbc6741999a1de2d359f0dd_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_1a6108940dbc6741999a1de2d359f0dd = L.geoJson(null, {
#                 onEachFeature: geo_json_1a6108940dbc6741999a1de2d359f0dd_onEachFeature,
#
#                 style: geo_json_1a6108940dbc6741999a1de2d359f0dd_styler,
#             ...{
# }
#         });
#
#         function geo_json_1a6108940dbc6741999a1de2d359f0dd_add (data) {
#             geo_json_1a6108940dbc6741999a1de2d359f0dd
#                 .addData(data);
#         }
#             geo_json_1a6108940dbc6741999a1de2d359f0dd_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-8.437439441911936, 43.170552959405214, 0.0], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_1a6108940dbc6741999a1de2d359f0dd.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Variable 1:&lt;/b&gt; https://api-features.idee.es//collections/railwaystationnode/items/FCEST_N150240000135
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             geo_json_1a6108940dbc6741999a1de2d359f0dd.addTo(map_bbd2e71568ec25faa6add74e7c661f9b);
#
#
#         function geo_json_0b37d6b8a5e537cc7d532cb8a41830b0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#3498db&quot;, &quot;fillColor&quot;: &quot;#3498db&quot;, &quot;fil

# %%
import folium
import ast
from IPython.display import display
import mercantile
from shapely import geometry

import sparql_virtualizer
import rdflib

g = rdflib.Graph()


x, y, z = 121,94, 8   # Ejemplo de coordenadas zxy
tile = mercantile.Tile(x=x, y=y, z=z)
print(tuple(mercantile.bounds(tile)))
aaa = geometry.box(*mercantile.bounds(tile)).wkt
print(aaa)

query = """
PREFIX ogc: <http://www.ogc.org/>
PREFIX ine: <https://lod.ine.es/voc/cubes/vocabulary#>
PREFIX sdmx-measure: <http://purl.org/linked-data/sdmx/2009/measure#>
PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX geof: <http://www.opengis.net/def/function/geosparql/>
PREFIX ex: <http://example.org/function/>
PREFIX qb: <http://purl.org/linked-data/cube#>
PREFIX dbo: <http://dbpedia.org/ontology/>

SELECT ?w ?gw WHERE {
    # ?w a dbo:RailwayStation ;
        geo:hasGeometry ?gw .
    FILTER (geof:sfWithin(?gw, \"""" + str(aaa) + """\"^^geo:wktLiteral))
} 
"""

qres = g.query(query)

# 1. Configuración base
# Usamos un mapa base oscuro para que los bordes de colores resalten más
m = folium.Map(location=[40.41, -3.70], zoom_start=6, tiles='CartoDB positron')
puntos_para_encuadre = []

# Paleta de colores más brillantes para que destaquen sobre fondo oscuro y con bordes
colores_paleta = ['#3498db', '#e74c3c', '#2ecc71', '#f1c40f', '#9b59b6', '#e67e22']

for row in qres:
    # Iteramos sobre la fila de 2 en 2
    for i in range(0, len(row), 2):
        try:
            uri = str(row[i])
            raw_geom = str(row[i+1])
            
            if not raw_geom.startswith("{"):
                continue

            geom_dict = ast.literal_eval(raw_geom)
            
            # Selección de color
            color_index = (i // 2) % len(colores_paleta)
            color_actual = colores_paleta[color_index]
            
            # CONFIGURACIÓN DE ESTILO PARA EVITAR OPACIDAD
            # Usamos una opacidad de relleno MUY baja (0.1 o 0.2)
            # Pero una opacidad de borde ALTA (1.0) y un peso de línea mayor
            def style_function(feature, color=color_actual):
                return {
                    'fillColor': color,   # Color de relleno
                    'fillOpacity': 0.01,   # MUY TRANSPARENTE por dentro (15%)
                    'color': color,       # Color del borde
                    'opacity': 1.0,        # BORDE TOTALMENTE OPACO
                    'weight': 3,          # BORDE GRUESO para que se vea bien el contorno
                }
            
            # Añadir al mapa con el estilo modificado
            folium.GeoJson(
                geom_dict,
                tooltip=f"<b>Variable {i//2 + 1}:</b> {uri}",
                style_function=style_function
            ).add_to(m)
            
            # Recolectar coordenadas para auto-zoom
            if 'coordinates' in geom_dict:
                coords = geom_dict['coordinates']
                if geom_dict['type'] == 'Polygon':
                    # Manejo de Polígonos y MultiPolígonos si fuera necesario
                    p = coords[0][0] # Primer punto del primer anillo
                    puntos_para_encuadre.append([p[1], p[0]])
                elif geom_dict['type'] == 'Point':
                    puntos_para_encuadre.append([coords[1], coords[0]])
                    
        except Exception:
            # Capturar errores de parsing de geometría o valores nulos
            continue

# 2. Ajuste de vista
if puntos_para_encuadre:
    m.fit_bounds(puntos_para_encuadre)

display(m)
print(m.get_bounds())
# Out:
# (-9.84375, 42.03297433244139, -8.4375, 43.06888777416962)
# POLYGON ((-8.4375 42.03297433244139, -8.4375 43.06888777416962, -9.84375 43.06888777416962, -9.84375 42.03297433244139, -8.4375 42.03297433244139))
# https://api-features.idee.es//collections/railwaystationnode/items?f=json&limit=10000&bbox=-9.84375%2C42.03297433244139%2C-8.4375%2C43.06888777416962
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1dd5f78c79c0700dd3d5356b3410c8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1dd5f78c79c0700dd3d5356b3410c8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1dd5f78c79c0700dd3d5356b3410c8b = L.map(
#                 &quot;map_c1dd5f78c79c0700dd3d5356b3410c8b&quot;,
#                 {
#                     center: [40.41, -3.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0706f0eac6b45b4eecb30488c88553c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0706f0eac6b45b4eecb30488c88553c.addTo(map_c1dd5f78c79c0700dd3d5356b3410c8b);
#
#
#         function geo_json_7dbb99226758019fb4ca5b506e992132_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#3498db&quot;, &quot;fillColor&quot;: &quot;#3498db&quot;, &quot;fillOpacity&quot;: 0.01, &quot;opacity&quot;: 1.0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_7dbb99226758019fb4ca5b506e992132_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_7dbb99226758019fb4ca5b506e992132 = L.geoJson(null, {
#                 onEachFeature: geo_json_7dbb99226758019fb4ca5b506e992132_onEachFeature,
#
#                 style: geo_json_7dbb99226758019fb4ca5b506e992132_styler,
#             ...{
# }
#         });
#
#         function geo_json_7dbb99226758019fb4ca5b506e992132_add (data) {
#             geo_json_7dbb99226758019fb4ca5b506e992132
#                 .addData(data);
#         }
#             geo_json_7dbb99226758019fb4ca5b506e992132_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-8.447864313022178, 43.038000222869435, 243.07600000000093], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_7dbb99226758019fb4ca5b506e992132.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Variable 1:&lt;/b&gt; https://api-features.idee.es//collections/railwaystationnode/items/FCEST_N150590000139
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             geo_json_7dbb99226758019fb4ca5b506e992132.addTo(map_c1dd5f78c79c0700dd3d5356b3410c8b);
#
#
#         function geo_json_ff6c22870c90006818935e9f213aa540_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#3498db&quot;, &quot;fillColor&quot;: &quot;#3498db&quot;, &quot;fillOpacity&quot;: 0.01, &quot;opacity&quot;: 1.0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_ff6c22870c90006818935e9f213aa540_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_ff6c22870c90006818935e9f213aa540 = L.geoJson(null, {
#                 onEachFeature: geo_json_ff6c22870c90006818935e9f213aa540_onEachFeature,
#
#                 style: geo_json_ff6c22870c90006818935e9f213aa540_styler,
#             ...{
# }
#         });
#
#         function geo_json_ff6c22870c90006818935e9f213aa540_add (data) {
#             geo_json_ff6c22870c90006818935e9f213aa540
#                 .addData(data);
#         }
#             geo_json_ff6c22870c90006818935e9f213aa540_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-8.652597764753919, 42.738984412806225, 7.903000000005704], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_ff6c22870c90006818935e9f213aa540.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Variable 1:&lt;/b&gt; https://api-features.idee.es//collections/railwaystationnode/items/FCEST_N150650000159
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             geo_json_ff6c22870c90006818935e9f213aa540.addTo(map_c1dd5f78c79c0700dd3d5356b3410c8b);
#
#
#         function geo_json_99b22e1f1ef9e3038170ae9a19aa2023_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#3498db&quot;, &quot;fillColor&quot;: &quot;#3498db
# [[42.055805166901145, -8.76746526963746], [43.038000222869435, -8.447864313022178]]

# %%
import ast
import threading
import time
import rdflib
import sparql_virtualizer
from IPython.display import display
from ipyleaflet import GeoJSON, LayersControl, Map, basemaps
from ipywidgets import Output, VBox, Button  # ← añadir Button

g = rdflib.Graph()
status = Output()
last_update_at = 0.0
update_in_progress = False
pending_bounds = None

def bounds_to_wkt(bounds):
    (south, west), (north, east) = bounds
    return (
        f"POLYGON(({west} {south}, {east} {south}, {east} {north}, "
        f"{west} {north}, {west} {south}))"
    )

def query_features(bounds):
    bbox_wkt = bounds_to_wkt(bounds)
    query = f"""
PREFIX ogc: <http://www.ogc.org/>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX geof: <http://www.opengis.net/def/function/geosparql/>
PREFIX dbo: <http://dbpedia.org/ontology/>
PREFIX geolinkeddata: <http://geo.linkeddata.es/ontology/> 
SELECT ?x ?gx WHERE {{
    # ?x a dbo:RailwayStation ;
        geo:hasGeometry ?gx .
    FILTER (geof:sfWithin(?gx, \"{bbox_wkt}\"^^geo:wktLiteral))
}}
"""
    features = []
    for uri, raw_geom in g.query(query):
        raw_geom = str(raw_geom)
        if not raw_geom.startswith("{"):
            continue
        try:
            geom = ast.literal_eval(raw_geom)
        except (SyntaxError, ValueError):
            continue
        features.append({
            "type": "Feature",
            "geometry": geom,
            "properties": {"uri": str(uri)},
        })
    return {"type": "FeatureCollection", "features": features}

geojson_layer = GeoJSON(
    data={"type": "FeatureCollection", "features": []},
    style={
        "color": "#e74c3c",
        "weight": 3,
        "opacity": 1.0,
        "fillOpacity": 0.05,
    },
    hover_style={"fillOpacity": 0.2},
    name="Railway stations",
)

m = Map(
    center=(40.41, -3.70),
    zoom=6,
    basemap=basemaps.CartoDB.Positron,
    scroll_wheel_zoom=True,
)
m.add_layer(geojson_layer)
m.add_control(LayersControl())

def refresh(bounds):
    global last_update_at, update_in_progress, pending_bounds
    if update_in_progress:
        pending_bounds = bounds
        return
    update_in_progress = True
    try:
        with status:
            status.clear_output(wait=True)
            print("Querying current bounding box...")
        data = query_features(bounds)
        geojson_layer.data = data
        last_update_at = time.monotonic()
        with status:
            status.clear_output(wait=True)
            print(f"Loaded {len(data['features'])} features for the current view.")
    except Exception as exc:
        with status:
            status.clear_output(wait=True)
            print(f"Error updating map: {exc}")
    finally:
        update_in_progress = False
        if pending_bounds is not None:
            next_bounds = pending_bounds
            pending_bounds = None
            refresh(next_bounds)

# ── Botón manual ──────────────────────────────────────────────
btn = Button(
    description="🔍 Buscar en esta zona",
    button_style="primary",
    layout={"width": "200px"},
)

def on_btn_click(_):
    bounds = m.bounds
    if bounds:
        threading.Thread(target=refresh, args=(bounds,), daemon=True).start()

btn.on_click(on_btn_click)
# ─────────────────────────────────────────────────────────────

# ← ya NO hay m.observe(on_bounds_change, ...)

display(VBox([btn, m, status]))
# Out:
# VBox(children=(Button(button_style='primary', description='🔍 Buscar en esta zona', layout=Layout(width='200px'…
